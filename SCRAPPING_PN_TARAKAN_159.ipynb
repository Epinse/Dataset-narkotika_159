# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url1 = 'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaee715a0b9c8eccad7a313131303035.html'
url2 = 'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaee7159eeb787268724313130393136.html'
url3 = 'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaee7159ba6aad908931313130373438.html'
url4 = 'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaee71599b71913892b8313130363536.html'
url5 = 'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaee715991467700a02d313130363339.html'
url6 = 'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaee51d84437637a8860303835323539.html'
url7 = 'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaee51d84256bda8ad1c303835323536.html'
url8 = 'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaee51d83f2f202086a2303835323530.html'
url9 = 'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaee51d83ddfb7a2aa25303835323438.html'
url10 = 'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaee51d835bed17a96e6303835323335.html'
url11 = 'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaee51d8313900588fa7303835323237.html'
url12 = 'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaee51d82e770d74beb1303835323232.html'
url13 = 'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaee4e15a04326c0b002313430323038.html'
url14 = 'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaee4d489d292afc8035313333343336.html'
url15 = 'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaee4d489c6d1600a193313333343335.html'
url16 = 'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaee4d48976eda12a507313333343236.html'
url17 = 'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaee4d4893e58f80878f313333343230.html'
url18 = 'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaee4bc551ac01f0b159313532323134.html'
url19 = 'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaee4bc48485f618bfb7313531363330.html'
url20 = 'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaee4bc48088c9e6b48e313531363233.html'
url21 = 'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaee4bc47bc92e288c9b313531363135.html'
url22 = 'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaee4bc4789d8bfe9d24313531363130.html'
url23 = 'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaee4bc4401d2186b6a2313531343335.html'
url24 = 'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaee4bc43ccdc120b388313531343330.html'
url25 = 'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaee4bc433a41752aa2c313531343134.html'
url26 = 'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaee4bc4330c7a6eb6c7313531343133.html'
url27 = 'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaee4bc3b152d3f68be6313531303336.html'
url28 = 'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaee4bc3a43ed7a0a104313531303134.html'
url29 = 'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaee4bc373e6bf329c72313530383533.html'
url30 = 'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaee4bc34425a2d68250313530373332.html'
url31 = 'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaee4bc33a8ad58ea59c313530373136.html'
url32 = 'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaee4bc32cc87fa0abd0313530363533.html'
url33 = 'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaee4bc32af25002a44e313530363530.html'
url34 = 'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaee4bc3219fdce0bf36313530363334.html'
url35 = 'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaee4bc31a8141d8b21d313530363233.html'
url36 = 'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaee4bc3109ce1a4b182313530363036.html'
url37 = 'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaee4bc308fb4f1c8c2d313530353533.html'
url38 = 'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaee4bc2a4984ec6aed2313530333035.html'
url39 = 'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaee4bc2a0a794acb363313530323538.html'
url40 = 'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaee4bc29d6b74fcb729313530323533.html'
url41 = 'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaee4bc1ad907e00a123313435363130.html'
url42 = 'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaee4bc1a6d93cc8812b313435353539.html'
url43 = 'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaee4bc1a555324e8d59313435353536.html'
url44 = 'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaee4bc295ba0f029f28313530323430.html'
url45 = 'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaee4bc275868b52afe8313530313436.html'
url46 = 'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaee4bc2736ea624bddf313530313432.html'
url47 = 'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaee4bc21f612d189e84313435393231.html'
url48 = 'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaee4bc21ec17f98b06a313435393230.html'
url49 = 'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaee4bc1b0fa9d0aa501313435363136.html'
url50 = 'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaee4bc1af7469708a9a313435363133.html'

page = requests.get(url)
soup = BeautifulSoup(page.text, 'html')

soup.find('table')
soup.find_all('table')

soup.find('table', class_ = 'table')
table = soup.find_all('table')

world_titles = soup.find_all('td', class_ = 'text-right')
world_table_titles = [title.text.strip() for title in world_titles]

df = pd.DataFrame(columns = world_table_titles)
column_data = soup.find_all('tr')

# Inisialisasi list kosong untuk kolom data
kolom_data = [[] for _ in range(19)]

# Mengiterasi melalui baris data
for row in column_data[1:19]:
    # Mengambil semua elemen 'td' dalam baris
    row_data = row.find_all('td')

    # Mengambil teks dari setiap 'td' dan memasukkannya ke dalam kolom yang sesuai
    for i, data in enumerate(row_data):
        if 'text-right' not in data.get('class', []):
            kolom_data[i].append(data.text.strip())

# Menghapus kolom yang kosong
kolom_data = [kolom for kolom in kolom_data if kolom]

# Cetak data dalam bentuk kolom
for kolom in kolom_data:
    print(kolom)

length = len(df)
df.loc[length] = kolom




page = requests.get(url2)
soup = BeautifulSoup(page.text, 'html')

column_data = soup.find_all('tr')

# Inisialisasi list kosong untuk kolom data
kolom_data = [[] for _ in range(19)]

# Mengiterasi melalui baris data
for row in column_data[1:19]:
    # Mengambil semua elemen 'td' dalam baris
    row_data = row.find_all('td')

    # Mengambil teks dari setiap 'td' dan memasukkannya ke dalam kolom yang sesuai
    for i, data in enumerate(row_data):
        if 'text-right' not in data.get('class', []):
            kolom_data[i].append(data.text.strip())

# Menghapus kolom yang kosong
kolom_data = [kolom for kolom in kolom_data if kolom]

# Cetak data dalam bentuk kolom
for kolom in kolom_data:
    print(kolom)

length = len(df)
df.loc[length] = kolom




page = requests.get(url3)
soup = BeautifulSoup(page.text, 'html')

column_data = soup.find_all('tr')

# Inisialisasi list kosong untuk kolom data
kolom_data = [[] for _ in range(19)]

# Mengiterasi melalui baris data
for row in column_data[1:19]:
    # Mengambil semua elemen 'td' dalam baris
    row_data = row.find_all('td')

    # Mengambil teks dari setiap 'td' dan memasukkannya ke dalam kolom yang sesuai
    for i, data in enumerate(row_data):
        if 'text-right' not in data.get('class', []):
            kolom_data[i].append(data.text.strip())

# Menghapus kolom yang kosong
kolom_data = [kolom for kolom in kolom_data if kolom]

# Cetak data dalam bentuk kolom
for kolom in kolom_data:
    print(kolom)

length = len(df)
df.loc[length] = kolom




page = requests.get(url4)
soup = BeautifulSoup(page.text, 'html')

column_data = soup.find_all('tr')

# Inisialisasi list kosong untuk kolom data
kolom_data = [[] for _ in range(19)]

# Mengiterasi melalui baris data
for row in column_data[1:19]:
    # Mengambil semua elemen 'td' dalam baris
    row_data = row.find_all('td')

    # Mengambil teks dari setiap 'td' dan memasukkannya ke dalam kolom yang sesuai
    for i, data in enumerate(row_data):
        if 'text-right' not in data.get('class', []):
            kolom_data[i].append(data.text.strip())

# Menghapus kolom yang kosong
kolom_data = [kolom for kolom in kolom_data if kolom]

# Cetak data dalam bentuk kolom
for kolom in kolom_data:
    print(kolom)

length = len(df)
df.loc[length] = kolom




page = requests.get(url5)
soup = BeautifulSoup(page.text, 'html')

column_data = soup.find_all('tr')

# Inisialisasi list kosong untuk kolom data
kolom_data = [[] for _ in range(19)]

# Mengiterasi melalui baris data
for row in column_data[1:19]:
    # Mengambil semua elemen 'td' dalam baris
    row_data = row.find_all('td')

    # Mengambil teks dari setiap 'td' dan memasukkannya ke dalam kolom yang sesuai
    for i, data in enumerate(row_data):
        if 'text-right' not in data.get('class', []):
            kolom_data[i].append(data.text.strip())

# Menghapus kolom yang kosong
kolom_data = [kolom for kolom in kolom_data if kolom]

# Cetak data dalam bentuk kolom
for kolom in kolom_data:
    print(kolom)

length = len(df)
df.loc[length] = kolom





page = requests.get(url6)
soup = BeautifulSoup(page.text, 'html')

column_data = soup.find_all('tr')

# Inisialisasi list kosong untuk kolom data
kolom_data = [[] for _ in range(19)]

# Mengiterasi melalui baris data
for row in column_data[1:19]:
    # Mengambil semua elemen 'td' dalam baris
    row_data = row.find_all('td')

    # Mengambil teks dari setiap 'td' dan memasukkannya ke dalam kolom yang sesuai
    for i, data in enumerate(row_data):
        if 'text-right' not in data.get('class', []):
            kolom_data[i].append(data.text.strip())

# Menghapus kolom yang kosong
kolom_data = [kolom for kolom in kolom_data if kolom]

# Cetak data dalam bentuk kolom
for kolom in kolom_data:
    print(kolom)

length = len(df)
df.loc[length] = kolom




page = requests.get(url7)
soup = BeautifulSoup(page.text, 'html')

column_data = soup.find_all('tr')

# Inisialisasi list kosong untuk kolom data
kolom_data = [[] for _ in range(19)]

# Mengiterasi melalui baris data
for row in column_data[1:19]:
    # Mengambil semua elemen 'td' dalam baris
    row_data = row.find_all('td')

    # Mengambil teks dari setiap 'td' dan memasukkannya ke dalam kolom yang sesuai
    for i, data in enumerate(row_data):
        if 'text-right' not in data.get('class', []):
            kolom_data[i].append(data.text.strip())

# Menghapus kolom yang kosong
kolom_data = [kolom for kolom in kolom_data if kolom]

# Cetak data dalam bentuk kolom
for kolom in kolom_data:
    print(kolom)

length = len(df)
df.loc[length] = kolom




page = requests.get(url8)
soup = BeautifulSoup(page.text, 'html')

column_data = soup.find_all('tr')

# Inisialisasi list kosong untuk kolom data
kolom_data = [[] for _ in range(19)]

# Mengiterasi melalui baris data
for row in column_data[1:19]:
    # Mengambil semua elemen 'td' dalam baris
    row_data = row.find_all('td')

    # Mengambil teks dari setiap 'td' dan memasukkannya ke dalam kolom yang sesuai
    for i, data in enumerate(row_data):
        if 'text-right' not in data.get('class', []):
            kolom_data[i].append(data.text.strip())

# Menghapus kolom yang kosong
kolom_data = [kolom for kolom in kolom_data if kolom]

# Cetak data dalam bentuk kolom
for kolom in kolom_data:
    print(kolom)

length = len(df)
df.loc[length] = kolom




page = requests.get(url9)
soup = BeautifulSoup(page.text, 'html')

column_data = soup.find_all('tr')

# Inisialisasi list kosong untuk kolom data
kolom_data = [[] for _ in range(19)]

# Mengiterasi melalui baris data
for row in column_data[1:19]:
    # Mengambil semua elemen 'td' dalam baris
    row_data = row.find_all('td')

    # Mengambil teks dari setiap 'td' dan memasukkannya ke dalam kolom yang sesuai
    for i, data in enumerate(row_data):
        if 'text-right' not in data.get('class', []):
            kolom_data[i].append(data.text.strip())

# Menghapus kolom yang kosong
kolom_data = [kolom for kolom in kolom_data if kolom]

# Cetak data dalam bentuk kolom
for kolom in kolom_data:
    print(kolom)

length = len(df)
df.loc[length] = kolom




page = requests.get(url9)
soup = BeautifulSoup(page.text, 'html')

column_data = soup.find_all('tr')

# Inisialisasi list kosong untuk kolom data
kolom_data = [[] for _ in range(19)]

# Mengiterasi melalui baris data
for row in column_data[1:19]:
    # Mengambil semua elemen 'td' dalam baris
    row_data = row.find_all('td')

    # Mengambil teks dari setiap 'td' dan memasukkannya ke dalam kolom yang sesuai
    for i, data in enumerate(row_data):
        if 'text-right' not in data.get('class', []):
            kolom_data[i].append(data.text.strip())

# Menghapus kolom yang kosong
kolom_data = [kolom for kolom in kolom_data if kolom]

# Cetak data dalam bentuk kolom
for kolom in kolom_data:
    print(kolom)

length = len(df)
df.loc[length] = kolom




page = requests.get(url10)
soup = BeautifulSoup(page.text, 'html')

column_data = soup.find_all('tr')

# Inisialisasi list kosong untuk kolom data
kolom_data = [[] for _ in range(19)]

# Mengiterasi melalui baris data
for row in column_data[1:19]:
    # Mengambil semua elemen 'td' dalam baris
    row_data = row.find_all('td')

    # Mengambil teks dari setiap 'td' dan memasukkannya ke dalam kolom yang sesuai
    for i, data in enumerate(row_data):
        if 'text-right' not in data.get('class', []):
            kolom_data[i].append(data.text.strip())

# Menghapus kolom yang kosong
kolom_data = [kolom for kolom in kolom_data if kolom]

# Cetak data dalam bentuk kolom
for kolom in kolom_data:
    print(kolom)

length = len(df)
df.loc[length] = kolom




page = requests.get(url11)
soup = BeautifulSoup(page.text, 'html')

column_data = soup.find_all('tr')

# Inisialisasi list kosong untuk kolom data
kolom_data = [[] for _ in range(19)]

# Mengiterasi melalui baris data
for row in column_data[1:19]:
    # Mengambil semua elemen 'td' dalam baris
    row_data = row.find_all('td')

    # Mengambil teks dari setiap 'td' dan memasukkannya ke dalam kolom yang sesuai
    for i, data in enumerate(row_data):
        if 'text-right' not in data.get('class', []):
            kolom_data[i].append(data.text.strip())

# Menghapus kolom yang kosong
kolom_data = [kolom for kolom in kolom_data if kolom]

# Cetak data dalam bentuk kolom
for kolom in kolom_data:
    print(kolom)

length = len(df)
df.loc[length] = kolom




page = requests.get(url12)
soup = BeautifulSoup(page.text, 'html')

column_data = soup.find_all('tr')

# Inisialisasi list kosong untuk kolom data
kolom_data = [[] for _ in range(19)]

# Mengiterasi melalui baris data
for row in column_data[1:19]:
    # Mengambil semua elemen 'td' dalam baris
    row_data = row.find_all('td')

    # Mengambil teks dari setiap 'td' dan memasukkannya ke dalam kolom yang sesuai
    for i, data in enumerate(row_data):
        if 'text-right' not in data.get('class', []):
            kolom_data[i].append(data.text.strip())

# Menghapus kolom yang kosong
kolom_data = [kolom for kolom in kolom_data if kolom]

# Cetak data dalam bentuk kolom
for kolom in kolom_data:
    print(kolom)

length = len(df)
df.loc[length] = kolom




page = requests.get(url13)
soup = BeautifulSoup(page.text, 'html')

column_data = soup.find_all('tr')

# Inisialisasi list kosong untuk kolom data
kolom_data = [[] for _ in range(19)]

# Mengiterasi melalui baris data
for row in column_data[1:19]:
    # Mengambil semua elemen 'td' dalam baris
    row_data = row.find_all('td')

    # Mengambil teks dari setiap 'td' dan memasukkannya ke dalam kolom yang sesuai
    for i, data in enumerate(row_data):
        if 'text-right' not in data.get('class', []):
            kolom_data[i].append(data.text.strip())

# Menghapus kolom yang kosong
kolom_data = [kolom for kolom in kolom_data if kolom]

# Cetak data dalam bentuk kolom
for kolom in kolom_data:
    print(kolom)

length = len(df)
df.loc[length] = kolom




page = requests.get(url14)
soup = BeautifulSoup(page.text, 'html')

column_data = soup.find_all('tr')

# Inisialisasi list kosong untuk kolom data
kolom_data = [[] for _ in range(19)]

# Mengiterasi melalui baris data
for row in column_data[1:19]:
    # Mengambil semua elemen 'td' dalam baris
    row_data = row.find_all('td')

    # Mengambil teks dari setiap 'td' dan memasukkannya ke dalam kolom yang sesuai
    for i, data in enumerate(row_data):
        if 'text-right' not in data.get('class', []):
            kolom_data[i].append(data.text.strip())

# Menghapus kolom yang kosong
kolom_data = [kolom for kolom in kolom_data if kolom]

# Cetak data dalam bentuk kolom
for kolom in kolom_data:
    print(kolom)

length = len(df)
df.loc[length] = kolom




page = requests.get(url15)
soup = BeautifulSoup(page.text, 'html')

column_data = soup.find_all('tr')

# Inisialisasi list kosong untuk kolom data
kolom_data = [[] for _ in range(19)]

# Mengiterasi melalui baris data
for row in column_data[1:19]:
    # Mengambil semua elemen 'td' dalam baris
    row_data = row.find_all('td')

    # Mengambil teks dari setiap 'td' dan memasukkannya ke dalam kolom yang sesuai
    for i, data in enumerate(row_data):
        if 'text-right' not in data.get('class', []):
            kolom_data[i].append(data.text.strip())

# Menghapus kolom yang kosong
kolom_data = [kolom for kolom in kolom_data if kolom]

# Cetak data dalam bentuk kolom
for kolom in kolom_data:
    print(kolom)

length = len(df)
df.loc[length] = kolom




page = requests.get(url16)
soup = BeautifulSoup(page.text, 'html')

column_data = soup.find_all('tr')

# Inisialisasi list kosong untuk kolom data
kolom_data = [[] for _ in range(19)]

# Mengiterasi melalui baris data
for row in column_data[1:19]:
    # Mengambil semua elemen 'td' dalam baris
    row_data = row.find_all('td')

    # Mengambil teks dari setiap 'td' dan memasukkannya ke dalam kolom yang sesuai
    for i, data in enumerate(row_data):
        if 'text-right' not in data.get('class', []):
            kolom_data[i].append(data.text.strip())

# Menghapus kolom yang kosong
kolom_data = [kolom for kolom in kolom_data if kolom]

# Cetak data dalam bentuk kolom
for kolom in kolom_data:
    print(kolom)

length = len(df)
df.loc[length] = kolom




page = requests.get(url17)
soup = BeautifulSoup(page.text, 'html')

column_data = soup.find_all('tr')

# Inisialisasi list kosong untuk kolom data
kolom_data = [[] for _ in range(19)]

# Mengiterasi melalui baris data
for row in column_data[1:19]:
    # Mengambil semua elemen 'td' dalam baris
    row_data = row.find_all('td')

    # Mengambil teks dari setiap 'td' dan memasukkannya ke dalam kolom yang sesuai
    for i, data in enumerate(row_data):
        if 'text-right' not in data.get('class', []):
            kolom_data[i].append(data.text.strip())

# Menghapus kolom yang kosong
kolom_data = [kolom for kolom in kolom_data if kolom]

# Cetak data dalam bentuk kolom
for kolom in kolom_data:
    print(kolom)

length = len(df)
df.loc[length] = kolom




page = requests.get(url18)
soup = BeautifulSoup(page.text, 'html')

column_data = soup.find_all('tr')

# Inisialisasi list kosong untuk kolom data
kolom_data = [[] for _ in range(19)]

# Mengiterasi melalui baris data
for row in column_data[1:19]:
    # Mengambil semua elemen 'td' dalam baris
    row_data = row.find_all('td')

    # Mengambil teks dari setiap 'td' dan memasukkannya ke dalam kolom yang sesuai
    for i, data in enumerate(row_data):
        if 'text-right' not in data.get('class', []):
            kolom_data[i].append(data.text.strip())

# Menghapus kolom yang kosong
kolom_data = [kolom for kolom in kolom_data if kolom]

# Cetak data dalam bentuk kolom
for kolom in kolom_data:
    print(kolom)

length = len(df)
df.loc[length] = kolom




page = requests.get(url19)
soup = BeautifulSoup(page.text, 'html')

column_data = soup.find_all('tr')

# Inisialisasi list kosong untuk kolom data
kolom_data = [[] for _ in range(19)]

# Mengiterasi melalui baris data
for row in column_data[1:19]:
    # Mengambil semua elemen 'td' dalam baris
    row_data = row.find_all('td')

    # Mengambil teks dari setiap 'td' dan memasukkannya ke dalam kolom yang sesuai
    for i, data in enumerate(row_data):
        if 'text-right' not in data.get('class', []):
            kolom_data[i].append(data.text.strip())

# Menghapus kolom yang kosong
kolom_data = [kolom for kolom in kolom_data if kolom]

# Cetak data dalam bentuk kolom
for kolom in kolom_data:
    print(kolom)

length = len(df)
df.loc[length] = kolom




page = requests.get(url20)
soup = BeautifulSoup(page.text, 'html')

column_data = soup.find_all('tr')

# Inisialisasi list kosong untuk kolom data
kolom_data = [[] for _ in range(19)]

# Mengiterasi melalui baris data
for row in column_data[1:19]:
    # Mengambil semua elemen 'td' dalam baris
    row_data = row.find_all('td')

    # Mengambil teks dari setiap 'td' dan memasukkannya ke dalam kolom yang sesuai
    for i, data in enumerate(row_data):
        if 'text-right' not in data.get('class', []):
            kolom_data[i].append(data.text.strip())

# Menghapus kolom yang kosong
kolom_data = [kolom for kolom in kolom_data if kolom]

# Cetak data dalam bentuk kolom
for kolom in kolom_data:
    print(kolom)

length = len(df)
df.loc[length] = kolom




page = requests.get(url21)
soup = BeautifulSoup(page.text, 'html')

column_data = soup.find_all('tr')

# Inisialisasi list kosong untuk kolom data
kolom_data = [[] for _ in range(19)]

# Mengiterasi melalui baris data
for row in column_data[1:19]:
    # Mengambil semua elemen 'td' dalam baris
    row_data = row.find_all('td')

    # Mengambil teks dari setiap 'td' dan memasukkannya ke dalam kolom yang sesuai
    for i, data in enumerate(row_data):
        if 'text-right' not in data.get('class', []):
            kolom_data[i].append(data.text.strip())

# Menghapus kolom yang kosong
kolom_data = [kolom for kolom in kolom_data if kolom]

# Cetak data dalam bentuk kolom
for kolom in kolom_data:
    print(kolom)

length = len(df)
df.loc[length] = kolom




page = requests.get(url22)
soup = BeautifulSoup(page.text, 'html')

column_data = soup.find_all('tr')

# Inisialisasi list kosong untuk kolom data
kolom_data = [[] for _ in range(19)]

# Mengiterasi melalui baris data
for row in column_data[1:19]:
    # Mengambil semua elemen 'td' dalam baris
    row_data = row.find_all('td')

    # Mengambil teks dari setiap 'td' dan memasukkannya ke dalam kolom yang sesuai
    for i, data in enumerate(row_data):
        if 'text-right' not in data.get('class', []):
            kolom_data[i].append(data.text.strip())

# Menghapus kolom yang kosong
kolom_data = [kolom for kolom in kolom_data if kolom]

# Cetak data dalam bentuk kolom
for kolom in kolom_data:
    print(kolom)

length = len(df)
df.loc[length] = kolom




page = requests.get(url23)
soup = BeautifulSoup(page.text, 'html')

column_data = soup.find_all('tr')

# Inisialisasi list kosong untuk kolom data
kolom_data = [[] for _ in range(19)]

# Mengiterasi melalui baris data
for row in column_data[1:19]:
    # Mengambil semua elemen 'td' dalam baris
    row_data = row.find_all('td')

    # Mengambil teks dari setiap 'td' dan memasukkannya ke dalam kolom yang sesuai
    for i, data in enumerate(row_data):
        if 'text-right' not in data.get('class', []):
            kolom_data[i].append(data.text.strip())

# Menghapus kolom yang kosong
kolom_data = [kolom for kolom in kolom_data if kolom]

# Cetak data dalam bentuk kolom
for kolom in kolom_data:
    print(kolom)

length = len(df)
df.loc[length] = kolom




page = requests.get(url24)
soup = BeautifulSoup(page.text, 'html')

column_data = soup.find_all('tr')

# Inisialisasi list kosong untuk kolom data
kolom_data = [[] for _ in range(19)]

# Mengiterasi melalui baris data
for row in column_data[1:19]:
    # Mengambil semua elemen 'td' dalam baris
    row_data = row.find_all('td')

    # Mengambil teks dari setiap 'td' dan memasukkannya ke dalam kolom yang sesuai
    for i, data in enumerate(row_data):
        if 'text-right' not in data.get('class', []):
            kolom_data[i].append(data.text.strip())

# Menghapus kolom yang kosong
kolom_data = [kolom for kolom in kolom_data if kolom]

# Cetak data dalam bentuk kolom
for kolom in kolom_data:
    print(kolom)

length = len(df)
df.loc[length] = kolom




page = requests.get(url25)
soup = BeautifulSoup(page.text, 'html')

column_data = soup.find_all('tr')

# Inisialisasi list kosong untuk kolom data
kolom_data = [[] for _ in range(19)]

# Mengiterasi melalui baris data
for row in column_data[1:19]:
    # Mengambil semua elemen 'td' dalam baris
    row_data = row.find_all('td')

    # Mengambil teks dari setiap 'td' dan memasukkannya ke dalam kolom yang sesuai
    for i, data in enumerate(row_data):
        if 'text-right' not in data.get('class', []):
            kolom_data[i].append(data.text.strip())

# Menghapus kolom yang kosong
kolom_data = [kolom for kolom in kolom_data if kolom]

# Cetak data dalam bentuk kolom
for kolom in kolom_data:
    print(kolom)

length = len(df)
df.loc[length] = kolom




page = requests.get(url26)
soup = BeautifulSoup(page.text, 'html')

column_data = soup.find_all('tr')

# Inisialisasi list kosong untuk kolom data
kolom_data = [[] for _ in range(19)]

# Mengiterasi melalui baris data
for row in column_data[1:19]:
    # Mengambil semua elemen 'td' dalam baris
    row_data = row.find_all('td')

    # Mengambil teks dari setiap 'td' dan memasukkannya ke dalam kolom yang sesuai
    for i, data in enumerate(row_data):
        if 'text-right' not in data.get('class', []):
            kolom_data[i].append(data.text.strip())

# Menghapus kolom yang kosong
kolom_data = [kolom for kolom in kolom_data if kolom]

# Cetak data dalam bentuk kolom
for kolom in kolom_data:
    print(kolom)

length = len(df)
df.loc[length] = kolom




page = requests.get(url27)
soup = BeautifulSoup(page.text, 'html')

column_data = soup.find_all('tr')

# Inisialisasi list kosong untuk kolom data
kolom_data = [[] for _ in range(19)]

# Mengiterasi melalui baris data
for row in column_data[1:19]:
    # Mengambil semua elemen 'td' dalam baris
    row_data = row.find_all('td')

    # Mengambil teks dari setiap 'td' dan memasukkannya ke dalam kolom yang sesuai
    for i, data in enumerate(row_data):
        if 'text-right' not in data.get('class', []):
            kolom_data[i].append(data.text.strip())

# Menghapus kolom yang kosong
kolom_data = [kolom for kolom in kolom_data if kolom]

# Cetak data dalam bentuk kolom
for kolom in kolom_data:
    print(kolom)

length = len(df)
df.loc[length] = kolom




page = requests.get(url28)
soup = BeautifulSoup(page.text, 'html')

column_data = soup.find_all('tr')

# Inisialisasi list kosong untuk kolom data
kolom_data = [[] for _ in range(19)]

# Mengiterasi melalui baris data
for row in column_data[1:19]:
    # Mengambil semua elemen 'td' dalam baris
    row_data = row.find_all('td')

    # Mengambil teks dari setiap 'td' dan memasukkannya ke dalam kolom yang sesuai
    for i, data in enumerate(row_data):
        if 'text-right' not in data.get('class', []):
            kolom_data[i].append(data.text.strip())

# Menghapus kolom yang kosong
kolom_data = [kolom for kolom in kolom_data if kolom]

# Cetak data dalam bentuk kolom
for kolom in kolom_data:
    print(kolom)

length = len(df)
df.loc[length] = kolom




page = requests.get(url29)
soup = BeautifulSoup(page.text, 'html')

column_data = soup.find_all('tr')

# Inisialisasi list kosong untuk kolom data
kolom_data = [[] for _ in range(19)]

# Mengiterasi melalui baris data
for row in column_data[1:19]:
    # Mengambil semua elemen 'td' dalam baris
    row_data = row.find_all('td')

    # Mengambil teks dari setiap 'td' dan memasukkannya ke dalam kolom yang sesuai
    for i, data in enumerate(row_data):
        if 'text-right' not in data.get('class', []):
            kolom_data[i].append(data.text.strip())

# Menghapus kolom yang kosong
kolom_data = [kolom for kolom in kolom_data if kolom]

# Cetak data dalam bentuk kolom
for kolom in kolom_data:
    print(kolom)

length = len(df)
df.loc[length] = kolom




page = requests.get(url30)
soup = BeautifulSoup(page.text, 'html')

column_data = soup.find_all('tr')

# Inisialisasi list kosong untuk kolom data
kolom_data = [[] for _ in range(19)]

# Mengiterasi melalui baris data
for row in column_data[1:19]:
    # Mengambil semua elemen 'td' dalam baris
    row_data = row.find_all('td')

    # Mengambil teks dari setiap 'td' dan memasukkannya ke dalam kolom yang sesuai
    for i, data in enumerate(row_data):
        if 'text-right' not in data.get('class', []):
            kolom_data[i].append(data.text.strip())

# Menghapus kolom yang kosong
kolom_data = [kolom for kolom in kolom_data if kolom]

# Cetak data dalam bentuk kolom
for kolom in kolom_data:
    print(kolom)

length = len(df)
df.loc[length] = kolom




page = requests.get(url31)
soup = BeautifulSoup(page.text, 'html')

column_data = soup.find_all('tr')

# Inisialisasi list kosong untuk kolom data
kolom_data = [[] for _ in range(19)]

# Mengiterasi melalui baris data
for row in column_data[1:19]:
    # Mengambil semua elemen 'td' dalam baris
    row_data = row.find_all('td')

    # Mengambil teks dari setiap 'td' dan memasukkannya ke dalam kolom yang sesuai
    for i, data in enumerate(row_data):
        if 'text-right' not in data.get('class', []):
            kolom_data[i].append(data.text.strip())

# Menghapus kolom yang kosong
kolom_data = [kolom for kolom in kolom_data if kolom]

# Cetak data dalam bentuk kolom
for kolom in kolom_data:
    print(kolom)

length = len(df)
df.loc[length] = kolom




page = requests.get(url32)
soup = BeautifulSoup(page.text, 'html')

column_data = soup.find_all('tr')

# Inisialisasi list kosong untuk kolom data
kolom_data = [[] for _ in range(19)]

# Mengiterasi melalui baris data
for row in column_data[1:19]:
    # Mengambil semua elemen 'td' dalam baris
    row_data = row.find_all('td')

    # Mengambil teks dari setiap 'td' dan memasukkannya ke dalam kolom yang sesuai
    for i, data in enumerate(row_data):
        if 'text-right' not in data.get('class', []):
            kolom_data[i].append(data.text.strip())

# Menghapus kolom yang kosong
kolom_data = [kolom for kolom in kolom_data if kolom]

# Cetak data dalam bentuk kolom
for kolom in kolom_data:
    print(kolom)

length = len(df)
df.loc[length] = kolom




page = requests.get(url33)
soup = BeautifulSoup(page.text, 'html')

column_data = soup.find_all('tr')

# Inisialisasi list kosong untuk kolom data
kolom_data = [[] for _ in range(19)]

# Mengiterasi melalui baris data
for row in column_data[1:19]:
    # Mengambil semua elemen 'td' dalam baris
    row_data = row.find_all('td')

    # Mengambil teks dari setiap 'td' dan memasukkannya ke dalam kolom yang sesuai
    for i, data in enumerate(row_data):
        if 'text-right' not in data.get('class', []):
            kolom_data[i].append(data.text.strip())

# Menghapus kolom yang kosong
kolom_data = [kolom for kolom in kolom_data if kolom]

# Cetak data dalam bentuk kolom
for kolom in kolom_data:
    print(kolom)

length = len(df)
df.loc[length] = kolom




page = requests.get(url34)
soup = BeautifulSoup(page.text, 'html')

column_data = soup.find_all('tr')

# Inisialisasi list kosong untuk kolom data
kolom_data = [[] for _ in range(19)]

# Mengiterasi melalui baris data
for row in column_data[1:19]:
    # Mengambil semua elemen 'td' dalam baris
    row_data = row.find_all('td')

    # Mengambil teks dari setiap 'td' dan memasukkannya ke dalam kolom yang sesuai
    for i, data in enumerate(row_data):
        if 'text-right' not in data.get('class', []):
            kolom_data[i].append(data.text.strip())

# Menghapus kolom yang kosong
kolom_data = [kolom for kolom in kolom_data if kolom]

# Cetak data dalam bentuk kolom
for kolom in kolom_data:
    print(kolom)

length = len(df)
df.loc[length] = kolom




page = requests.get(url35)
soup = BeautifulSoup(page.text, 'html')

column_data = soup.find_all('tr')

# Inisialisasi list kosong untuk kolom data
kolom_data = [[] for _ in range(19)]

# Mengiterasi melalui baris data
for row in column_data[1:19]:
    # Mengambil semua elemen 'td' dalam baris
    row_data = row.find_all('td')

    # Mengambil teks dari setiap 'td' dan memasukkannya ke dalam kolom yang sesuai
    for i, data in enumerate(row_data):
        if 'text-right' not in data.get('class', []):
            kolom_data[i].append(data.text.strip())

# Menghapus kolom yang kosong
kolom_data = [kolom for kolom in kolom_data if kolom]

# Cetak data dalam bentuk kolom
for kolom in kolom_data:
    print(kolom)

length = len(df)
df.loc[length] = kolom




page = requests.get(url36)
soup = BeautifulSoup(page.text, 'html')

column_data = soup.find_all('tr')

# Inisialisasi list kosong untuk kolom data
kolom_data = [[] for _ in range(19)]

# Mengiterasi melalui baris data
for row in column_data[1:19]:
    # Mengambil semua elemen 'td' dalam baris
    row_data = row.find_all('td')

    # Mengambil teks dari setiap 'td' dan memasukkannya ke dalam kolom yang sesuai
    for i, data in enumerate(row_data):
        if 'text-right' not in data.get('class', []):
            kolom_data[i].append(data.text.strip())

# Menghapus kolom yang kosong
kolom_data = [kolom for kolom in kolom_data if kolom]

# Cetak data dalam bentuk kolom
for kolom in kolom_data:
    print(kolom)

length = len(df)
df.loc[length] = kolom




page = requests.get(url37)
soup = BeautifulSoup(page.text, 'html')

column_data = soup.find_all('tr')

# Inisialisasi list kosong untuk kolom data
kolom_data = [[] for _ in range(19)]

# Mengiterasi melalui baris data
for row in column_data[1:19]:
    # Mengambil semua elemen 'td' dalam baris
    row_data = row.find_all('td')

    # Mengambil teks dari setiap 'td' dan memasukkannya ke dalam kolom yang sesuai
    for i, data in enumerate(row_data):
        if 'text-right' not in data.get('class', []):
            kolom_data[i].append(data.text.strip())

# Menghapus kolom yang kosong
kolom_data = [kolom for kolom in kolom_data if kolom]

# Cetak data dalam bentuk kolom
for kolom in kolom_data:
    print(kolom)

length = len(df)
df.loc[length] = kolom




page = requests.get(url38)
soup = BeautifulSoup(page.text, 'html')

column_data = soup.find_all('tr')

# Inisialisasi list kosong untuk kolom data
kolom_data = [[] for _ in range(19)]

# Mengiterasi melalui baris data
for row in column_data[1:19]:
    # Mengambil semua elemen 'td' dalam baris
    row_data = row.find_all('td')

    # Mengambil teks dari setiap 'td' dan memasukkannya ke dalam kolom yang sesuai
    for i, data in enumerate(row_data):
        if 'text-right' not in data.get('class', []):
            kolom_data[i].append(data.text.strip())

# Menghapus kolom yang kosong
kolom_data = [kolom for kolom in kolom_data if kolom]

# Cetak data dalam bentuk kolom
for kolom in kolom_data:
    print(kolom)

length = len(df)
df.loc[length] = kolom




page = requests.get(url39)
soup = BeautifulSoup(page.text, 'html')

column_data = soup.find_all('tr')

# Inisialisasi list kosong untuk kolom data
kolom_data = [[] for _ in range(19)]

# Mengiterasi melalui baris data
for row in column_data[1:19]:
    # Mengambil semua elemen 'td' dalam baris
    row_data = row.find_all('td')

    # Mengambil teks dari setiap 'td' dan memasukkannya ke dalam kolom yang sesuai
    for i, data in enumerate(row_data):
        if 'text-right' not in data.get('class', []):
            kolom_data[i].append(data.text.strip())

# Menghapus kolom yang kosong
kolom_data = [kolom for kolom in kolom_data if kolom]

# Cetak data dalam bentuk kolom
for kolom in kolom_data:
    print(kolom)

length = len(df)
df.loc[length] = kolom




page = requests.get(url40)
soup = BeautifulSoup(page.text, 'html')

column_data = soup.find_all('tr')

# Inisialisasi list kosong untuk kolom data
kolom_data = [[] for _ in range(19)]

# Mengiterasi melalui baris data
for row in column_data[1:19]:
    # Mengambil semua elemen 'td' dalam baris
    row_data = row.find_all('td')

    # Mengambil teks dari setiap 'td' dan memasukkannya ke dalam kolom yang sesuai
    for i, data in enumerate(row_data):
        if 'text-right' not in data.get('class', []):
            kolom_data[i].append(data.text.strip())

# Menghapus kolom yang kosong
kolom_data = [kolom for kolom in kolom_data if kolom]

# Cetak data dalam bentuk kolom
for kolom in kolom_data:
    print(kolom)

length = len(df)
df.loc[length] = kolom




page = requests.get(url41)
soup = BeautifulSoup(page.text, 'html')

column_data = soup.find_all('tr')

# Inisialisasi list kosong untuk kolom data
kolom_data = [[] for _ in range(19)]

# Mengiterasi melalui baris data
for row in column_data[1:19]:
    # Mengambil semua elemen 'td' dalam baris
    row_data = row.find_all('td')

    # Mengambil teks dari setiap 'td' dan memasukkannya ke dalam kolom yang sesuai
    for i, data in enumerate(row_data):
        if 'text-right' not in data.get('class', []):
            kolom_data[i].append(data.text.strip())

# Menghapus kolom yang kosong
kolom_data = [kolom for kolom in kolom_data if kolom]

# Cetak data dalam bentuk kolom
for kolom in kolom_data:
    print(kolom)

length = len(df)
df.loc[length] = kolom




page = requests.get(url42)
soup = BeautifulSoup(page.text, 'html')

column_data = soup.find_all('tr')

# Inisialisasi list kosong untuk kolom data
kolom_data = [[] for _ in range(19)]

# Mengiterasi melalui baris data
for row in column_data[1:19]:
    # Mengambil semua elemen 'td' dalam baris
    row_data = row.find_all('td')

    # Mengambil teks dari setiap 'td' dan memasukkannya ke dalam kolom yang sesuai
    for i, data in enumerate(row_data):
        if 'text-right' not in data.get('class', []):
            kolom_data[i].append(data.text.strip())

# Menghapus kolom yang kosong
kolom_data = [kolom for kolom in kolom_data if kolom]

# Cetak data dalam bentuk kolom
for kolom in kolom_data:
    print(kolom)

length = len(df)
df.loc[length] = kolom

page = requests.get(url43)
soup = BeautifulSoup(page.text, 'html')

column_data = soup.find_all('tr')

# Inisialisasi list kosong untuk kolom data
kolom_data = [[] for _ in range(19)]

# Mengiterasi melalui baris data
for row in column_data[1:19]:
    # Mengambil semua elemen 'td' dalam baris
    row_data = row.find_all('td')

    # Mengambil teks dari setiap 'td' dan memasukkannya ke dalam kolom yang sesuai
    for i, data in enumerate(row_data):
        if 'text-right' not in data.get('class', []):
            kolom_data[i].append(data.text.strip())

# Menghapus kolom yang kosong
kolom_data = [kolom for kolom in kolom_data if kolom]

# Cetak data dalam bentuk kolom
for kolom in kolom_data:
    print(kolom)

length = len(df)
df.loc[length] = kolom




page = requests.get(url44)
soup = BeautifulSoup(page.text, 'html')

column_data = soup.find_all('tr')

# Inisialisasi list kosong untuk kolom data
kolom_data = [[] for _ in range(19)]

# Mengiterasi melalui baris data
for row in column_data[1:19]:
    # Mengambil semua elemen 'td' dalam baris
    row_data = row.find_all('td')

    # Mengambil teks dari setiap 'td' dan memasukkannya ke dalam kolom yang sesuai
    for i, data in enumerate(row_data):
        if 'text-right' not in data.get('class', []):
            kolom_data[i].append(data.text.strip())

# Menghapus kolom yang kosong
kolom_data = [kolom for kolom in kolom_data if kolom]

# Cetak data dalam bentuk kolom
for kolom in kolom_data:
    print(kolom)

length = len(df)
df.loc[length] = kolom




page = requests.get(url45)
soup = BeautifulSoup(page.text, 'html')

column_data = soup.find_all('tr')

# Inisialisasi list kosong untuk kolom data
kolom_data = [[] for _ in range(19)]

# Mengiterasi melalui baris data
for row in column_data[1:19]:
    # Mengambil semua elemen 'td' dalam baris
    row_data = row.find_all('td')

    # Mengambil teks dari setiap 'td' dan memasukkannya ke dalam kolom yang sesuai
    for i, data in enumerate(row_data):
        if 'text-right' not in data.get('class', []):
            kolom_data[i].append(data.text.strip())

# Menghapus kolom yang kosong
kolom_data = [kolom for kolom in kolom_data if kolom]

# Cetak data dalam bentuk kolom
for kolom in kolom_data:
    print(kolom)

length = len(df)
df.loc[length] = kolom




page = requests.get(url46)
soup = BeautifulSoup(page.text, 'html')

column_data = soup.find_all('tr')

# Inisialisasi list kosong untuk kolom data
kolom_data = [[] for _ in range(19)]

# Mengiterasi melalui baris data
for row in column_data[1:19]:
    # Mengambil semua elemen 'td' dalam baris
    row_data = row.find_all('td')

    # Mengambil teks dari setiap 'td' dan memasukkannya ke dalam kolom yang sesuai
    for i, data in enumerate(row_data):
        if 'text-right' not in data.get('class', []):
            kolom_data[i].append(data.text.strip())

# Menghapus kolom yang kosong
kolom_data = [kolom for kolom in kolom_data if kolom]

# Cetak data dalam bentuk kolom
for kolom in kolom_data:
    print(kolom)

length = len(df)
df.loc[length] = kolom




page = requests.get(url47)
soup = BeautifulSoup(page.text, 'html')

column_data = soup.find_all('tr')

# Inisialisasi list kosong untuk kolom data
kolom_data = [[] for _ in range(19)]

# Mengiterasi melalui baris data
for row in column_data[1:19]:
    # Mengambil semua elemen 'td' dalam baris
    row_data = row.find_all('td')

    # Mengambil teks dari setiap 'td' dan memasukkannya ke dalam kolom yang sesuai
    for i, data in enumerate(row_data):
        if 'text-right' not in data.get('class', []):
            kolom_data[i].append(data.text.strip())

# Menghapus kolom yang kosong
kolom_data = [kolom for kolom in kolom_data if kolom]

# Cetak data dalam bentuk kolom
for kolom in kolom_data:
    print(kolom)

length = len(df)
df.loc[length] = kolom




page = requests.get(url48)
soup = BeautifulSoup(page.text, 'html')

column_data = soup.find_all('tr')

# Inisialisasi list kosong untuk kolom data
kolom_data = [[] for _ in range(19)]

# Mengiterasi melalui baris data
for row in column_data[1:19]:
    # Mengambil semua elemen 'td' dalam baris
    row_data = row.find_all('td')

    # Mengambil teks dari setiap 'td' dan memasukkannya ke dalam kolom yang sesuai
    for i, data in enumerate(row_data):
        if 'text-right' not in data.get('class', []):
            kolom_data[i].append(data.text.strip())

# Menghapus kolom yang kosong
kolom_data = [kolom for kolom in kolom_data if kolom]

# Cetak data dalam bentuk kolom
for kolom in kolom_data:
    print(kolom)

length = len(df)
df.loc[length] = kolom




page = requests.get(url49)
soup = BeautifulSoup(page.text, 'html')

column_data = soup.find_all('tr')

# Inisialisasi list kosong untuk kolom data
kolom_data = [[] for _ in range(19)]

# Mengiterasi melalui baris data
for row in column_data[1:19]:
    # Mengambil semua elemen 'td' dalam baris
    row_data = row.find_all('td')

    # Mengambil teks dari setiap 'td' dan memasukkannya ke dalam kolom yang sesuai
    for i, data in enumerate(row_data):
        if 'text-right' not in data.get('class', []):
            kolom_data[i].append(data.text.strip())

# Menghapus kolom yang kosong
kolom_data = [kolom for kolom in kolom_data if kolom]

# Cetak data dalam bentuk kolom
for kolom in kolom_data:
    print(kolom)

length = len(df)
df.loc[length] = kolom




page = requests.get(url50)
soup = BeautifulSoup(page.text, 'html')

column_data = soup.find_all('tr')

# Inisialisasi list kosong untuk kolom data
kolom_data = [[] for _ in range(19)]

# Mengiterasi melalui baris data
for row in column_data[1:19]:
    # Mengambil semua elemen 'td' dalam baris
    row_data = row.find_all('td')

    # Mengambil teks dari setiap 'td' dan memasukkannya ke dalam kolom yang sesuai
    for i, data in enumerate(row_data):
        if 'text-right' not in data.get('class', []):
            kolom_data[i].append(data.text.strip())

# Menghapus kolom yang kosong
kolom_data = [kolom for kolom in kolom_data if kolom]

# Cetak data dalam bentuk kolom
for kolom in kolom_data:
    print(kolom)

length = len(df)
df.loc[length] = kolom
# Out:
# ['221/Pid.Sus/2023/PN Bln', 'Pertama', 'Pidana Khusus  Narkotika dan Psikotropika \n Pidana Khusus  Narkotika dan Psikotropika', 'Narkotika', '2023', '4 September 2023', 'PN BATULICIN', 'PN', 'Hakim Ketua Fendy Aditiya Siswa Yulianto', 'Hakim Anggota  Bayu Dwi Putra, M.hbr Hakim Anggota  Andi Rachmad Sulistiyanto', 'Panitera Pengganti: Ahmad Makasidik Tasrih', 'Lain-lain', 'PIDANA PENJARA WAKTU TERTENTU', 'Menyatakan Terdakwa AYU SARPIYAH Binti SEGAR SAID terbukti secara sah dan meyakinkan bersalah melakukan tindak pidana secara Tanpa hak Menjual Narkotika Golongan I bukan tanaman yang beratnya melebihi 5 (lima) gram sebagaimana dalam Dakwaan Primair; 2. Menjatuhkan pidana terhadap Terdakwa AYU SARPIYAH Binti SEGAR SAID dengan pidana penjara selama selama 7 (Tujuh) tahun dan 6 (Enam) Bulan dan denda sejumlah Rp. 2.000.000.000,- (Dua miliar rupiah), dengan ketentuan apabila denda tersebut tidak dibayar maka diganti dengan pidana penjara selama 5 (Lima) bulan; 3. Menetapkan masa penang
# ...

# %%
df
# Out:
#                       Nomor Tingkat Proses  \
# 0   221/Pid.Sus/2023/PN Bln        Pertama
# 1   118/Pid.Sus/2023/PN Tar        Pertama
# 2    79/Pid.Sus/2023/PN Tar        Pertama
# 3   174/Pid.Sus/2023/PN Tar        Pertama
# 4   144/Pid.Sus/2023/PN Tar        Pertama
# 5   119/Pid.Sus/2023/PN Tar        Pertama
# 6   100/Pid.Sus/2023/PN Tar        Pertama
# 7    99/Pid.Sus/2023/PN Tar        Pertama
# 8    98/Pid.Sus/2023/PN Tar        Pertama
# 9    98/Pid.Sus/2023/PN Tar        Pertama
# 10  130/Pid.Sus/2023/PN Tar        Pertama
# 11  156/Pid.Sus/2023/PN Tar        Pertama
# 12  172/Pid.Sus/2023/PN Tar        Pertama
# 13  101/Pid.Sus/2023/PN Tar        Pertama
# 14  178/Pid.Sus/2023/PN Tar        Pertama
# 15  177/Pid.Sus/2023/PN Tar        Pertama
# 16   35/Pid.Sus/2023/PN Tar        Pertama
# 17   66/Pid.Sus/2023/PN Tar        Pertama
# 18  289/Pid.Sus/2021/PN Tar        Pertama
# 19  311/Pid.Sus/2021/PN Tar        Pertama
# 20  324/Pid.Sus/2021/PN Tar        Pertama
# ...

# %%
df.to_csv('pn_tarakan.csv', index = False)
